# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/mcc_2024_scorecard.csv")

# %%
df.head()
# Out:
#             country_name  health_score  political_rights_score  \
# 0                  Kenya          2.03                      22
# 1             Mauritania          1.35                      14
# 2  Micronesia, Fed. Sts.          2.79                      37
# 3                Vietnam          2.11                       4
# 4          Côte d'Ivoire          1.37                      19
#
#    civil_liberties_score  control_of_corruption_score  \
# 0                     30                    -0.218753
# 1                     22                    -0.257896
# 2                     55                     1.025068
# 3                     15                     0.253666
# 4                     30                     0.192352
#
#    government_effectiveness_score  rule_of_law_score  \
# 0                        0.124339           0.000000
# 1                       -0.276115          -0.336692
# 2                        0.804748           1.008060
# ...

# %%
df.tail()
# Out:
#         country_name  health_score  political_rights_score  \
# 75           Comoros          0.77                      16
# 76           Eritrea          0.85                       1
# 77  Korea, Dem. Rep.           NaN                       0
# 78              Mali          1.48                       8
# 79        Mozambique          2.42                      14
#
#     civil_liberties_score  control_of_corruption_score  \
# 75                     26                    -0.143383
# 76                      2                    -0.181072
# 77                      3                    -0.505068
# 78                     21                     0.221581
# 79                     31                     0.264642
#
#     government_effectiveness_score  rule_of_law_score  \
# 75                       -0.647389          -0.291813
# 76                       -0.695281          -0.749482
# 77                       -0.427862          -0.639182
# ...

# %%
df.describe()
# Out:
#        health_score  political_rights_score  civil_liberties_score  \
# count     76.000000               80.000000              80.000000
# mean       2.188553               15.112500              24.962500
# std        1.535210               11.878066              13.643233
# min        0.410000               -3.000000               2.000000
# 25%        1.070000                4.000000              14.750000
# 50%        1.895000               14.000000              24.000000
# 75%        2.890000               25.250000              33.000000
# max        9.290000               38.000000              55.000000
#
#        control_of_corruption_score  government_effectiveness_score  \
# count                    80.000000                       80.000000
# mean                      0.155319                       -0.020817
# std                       0.567444                        0.541213
# min                      -0.754725                       -1.354742
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   country_name                            80 non-null     object
#  1   health_score                            76 non-null     float64
#  2   political_rights_score                  80 non-null     int64
#  3   civil_liberties_score                   80 non-null     int64
#  4   control_of_corruption_score             80 non-null     float64
#  5   government_effectiveness_score          80 non-null     float64
#  6   rule_of_law_score                       80 non-null     float64
#  7   freedom_of_information_score            75 non-null     float64
#  8   immunization_score                      80 non-null     float64
#  9   education_expenditures_score            69 non-null     float64
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of              country_name  health_score  political_rights_score  \
# 0                   Kenya          2.03                      22
# 1              Mauritania          1.35                      14
# 2   Micronesia, Fed. Sts.          2.79                      37
# 3                 Vietnam          2.11                       4
# 4           Côte d'Ivoire          1.37                      19
# ..                    ...           ...                     ...
# 75                Comoros          0.77                      16
# 76                Eritrea          0.85                       1
# 77       Korea, Dem. Rep.           NaN                       0
# 78                   Mali          1.48                       8
# 79             Mozambique          2.42                      14
#
#     civil_liberties_score  control_of_corruption_score  \
# 0                      30                    -0.218753
# ...

# %%
df.isnull().sum()
# Out:
# country_name                               0
# health_score                               4
# political_rights_score                     0
# civil_liberties_score                      0
# control_of_corruption_score                0
# government_effectiveness_score             0
# rule_of_law_score                          0
# freedom_of_information_score               5
# immunization_score                         0
# education_expenditures_score              11
# child_health_score                         0
# natural_resource_protection_score          5
# regulatory_quality_score                   0
# land_rights_and_access_score               3
# employment_opportunity_score               0
# trade_policy_score                         5
# inflation_score                            3
# fiscal_policy_score                        3
# access_to_credit_score                     2
# gender_in_the_economy_score                1
# girls_education_enrollment_rates_score    19
# ...

# %%
# Impute missing values with mean for specific columns
columns_to_impute = ['health_score', 'freedom_of_information_score', 'education_expenditures_score',
                     'natural_resource_protection_score', 'land_rights_and_access_score', 'trade_policy_score',
                     'inflation_score', 'fiscal_policy_score', 'access_to_credit_score', 'gender_in_the_economy_score',
                     'girls_education_enrollment_rates_score']

for col in columns_to_impute:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Calculate correlation matrix (with numeric_only=True)
corr_matrix = df.corr(numeric_only=True)

# Create heatmap with annotations
plt.imshow(corr_matrix, cmap='coolwarm')
plt.colorbar()

# Add annotations manually
for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        text = f"{corr_matrix.iloc[i, j]:.2f}"
        plt.annotate(text, xy=(j, i), ha='center', va='center')

plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=45, ha='left')
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.title("Correlation Matrix for MCC Dataset")
plt.show()

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv("/content/mcc_2024_scorecard.csv")  # Replace with your actual file path

# Select numeric columns
numeric_columns = df.select_dtypes(include=["int64", "float64"])

# Calculate the correlation matrix for numeric columns
corr_matrix = numeric_columns.corr()

# Print the correlation matrix in text format, rounded to 2 decimal places
print(corr_matrix.round(2).to_string())
# Out:
#                                         health_score  political_rights_score  civil_liberties_score  control_of_corruption_score  government_effectiveness_score  rule_of_law_score  freedom_of_information_score  immunization_score  education_expenditures_score  child_health_score  natural_resource_protection_score  regulatory_quality_score  land_rights_and_access_score  employment_opportunity_score  trade_policy_score  inflation_score  fiscal_policy_score  access_to_credit_score  gender_in_the_economy_score  girls_education_enrollment_rates_score
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Assuming your dataset is in a CSV file named "data.csv"
df = pd.read_csv("/content/mcc_2024_scorecard.csv")

# %%
health_scores = df["health_score"]
government_effectiveness_scores = df["government_effectiveness_score"]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(government_effectiveness_scores, health_scores)
plt.xlabel("Government Effectiveness Score")
plt.ylabel("Health Score")
plt.title("Correlation between Health Score and Government Effectiveness")
plt.show()

# %%
# Calculate average health scores per country
avg_health_scores_per_country = df.groupby("country_name")["health_score"].mean()

# Create the bar plot
plt.figure(figsize=(12, 6))
plt.bar(avg_health_scores_per_country.index, avg_health_scores_per_country.values)
plt.xlabel("Country Name")
plt.ylabel("Average Health Score")
plt.title("Bar Plot of Average Health Scores per Country")
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# # Strong Positive Correlations (0.7 and above):
#
# # health_score and education_expenditures_score (0.71): This suggests a strong positive relationship between health outcomes and investments in education.
# # health_score and child_health_score (0.39): This indicates a positive association between overall health and specific measures of child health.
# # regulatory_quality_score and control_of_corruption_score (0.70): This suggests that countries with better regulatory quality tend to have stronger control over corruption.
# # regulatory_quality_score and government_effectiveness_score (0.78): This points to a strong link between effective regulation and overall government effectiveness.
# #  Moderate Positive Correlations (0.4 to 0.7):
#
# # health_score and political_rights_score (0.40), civil_liberties_score (0.44): This suggests potential connections between health outcomes and political freedoms.
# # political_rights_score and civil_liberties_score (0.93): This highlights a very strong relationship between these two measures of political rights.
# # education_expenditures_score and land_rights_and_access_score (0.27), employment_opportunity_score (0.07), girls_education_enrollment_rates_score (0.25): This suggests potential links between education spending and other development factors.
# #  Negative Correlations:
#
# # fiscal_policy_score and political_rights_score (-0.30), civil_liberties_score (-0.20), freedom_of_information_score (-0.20), immunization_score (-0.31): This suggests potential negative relationships between fiscal policy and certain aspects of governance and health.
# # inflation_score and control_of_corruption_score (-0.20), government_effectiveness_score (-0.27), rule_of_law_score (-0.17): This indicates potential negative associations between inflation and governance indicators.
# #  Additional Insights:
#
# # child_health_score has a negative correlation with natural_resource_protection_score (-0.23), suggesting a potential need to investigate the relationship between child health and environmental factors.
